# %%
# %matplotlib inline

# %%
from sklearn import datasets,cluster
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

# %%
np.random.seed(2)

# %%
iris=datasets.load_iris()

# %%
X_iris=iris.data
y_iris=iris.target

# %%
k_means=cluster.KMeans(n_clusters=3)
k_means.fit(X_iris)
labels=k_means.labels_

# %%
correc_labels=sum(y_iris==labels)

print("Sonuc %d out of % samples were correctly  labeled " % (correc_labels,y_iris.size))
# Out:
# Sonuc 134 out of 150amples were correctly  labeled

# %%
fig=plt.figure(1,figsize=(8,8))
plt.clf()
ax=Axes3D(fig,rect=[0,0,1,1],elev=8,azim=200)
plt.cla()

ax.scatter(X_iris[:,3],X_iris[:,0],X_iris[:,2],c=labels.astype(np.float))

ax.w_xaxis.set_ticklabels([])
ax.w_xaxis.set_ticklabels([])
ax.w_xaxis.set_ticklabels([])
ax.set_xlabel('Petal width')
ax.set_xlabel('Sepal length')
ax.set_xlabel('Petal length')

plt.show()
